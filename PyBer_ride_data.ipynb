# %%
# Add the magic command
# %matplotlib inline
# Import the following dependencies:
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics
# Load in csv. Read PyBer_ride_data into a Pandas DataFrame.
pyber_ride_df = pd.read_csv("Resources/PyBer_ride_data.csv")
pyber_ride_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
# Adjust the x-ticks to show all the months
# Set x-axis and tick locations.
x_axis = np.arange(len(pyber_ride_df))
tick_locations = [value for value in x_axis]
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Plot the months along the x-axis and the fare on the y-axis.
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.xticks(tick_locations, pyber_ride_df["Month"])
plt.show()

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
# Create a bar chart with the same data"chain" the bar() function to the plot() function.
pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
# To add the kind parameter to the plot() function.
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar')
plt.show()

# %%
# Skill Drill
# Create a bar chart with the following annotations:

stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar')
plt.bar(x_axis, y_axis, capsize=5, yerr=stdev)
#plt.errorbar(x_axis, y_axis, c='r')
plt.yticks(np.arange(0,51,5))
plt.savefig("test_Pyber_ride.png")

# %%
plt.bar(x_axis, y_axis, capsize=3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
