# %%
# %matplotlib inline

# %%
# Import dependencies
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-08fd7066f10a> in <module>
#       1 # Get the standard deviation of the values in the y-axis.
# ----> 2 stdev = statistics.stdev(y_axis)
#       3 stdev
#
# NameError: name 'statistics' is not defined

# %%
# Create the plot, the figure with the current axes.
plt.plot(x_axis, y_axis)

# %%
# Create the plot with as.plt()
# Create an Object Oriented Interface plot
# NOTE: This may also be written as fig = plt.figure() next ln: ax = fig.add_subplot()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt(). To type code another way.
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create and annotate the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the ylimit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
ax.set.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# set the x limit to show months Jan thru Jun
plt.xlim("Jan", "June")
# Set the axis' to figure size to 20 pixels wide by 10 pixesls high.
plt.figure(figsize=(20, 10))
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend("Boston")
# Out:
# No handles with labels found to put in legend.

# %%
# Skill Drill
# Change the size of the figure
fig, ax = plt.subplots(figsize=(5, 5))
# Create the plot.
ax.plot(x_axis, y_axis, marker="*", color="green", linewidth=2, label='Boston')
# Create labels for the x and y axes.
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
# Set the y limit between 0 and 45.
ax.set_ylim(0, 45)
# Create a title.
ax.set_title("PyBer Fare by Month")
# Add a grid.
ax.grid()
# Add the legend.
ax.legend()

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the Horizontal Bar Chart plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the Horizontal bar chart plot.
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the Horizontal Bar Chart plot with inverted month label.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create the plot.
plt.barh(x_axis, y_axis, color="magenta", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Invert the month label.
plt.gca().invert_yaxis()
# Add the legend.
plt.legend()

# %%
# Create an Object Oriented Bar Chart with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create an Object Oriented Bar Chart with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color="k", label="New York")
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt() Horizontal Bar chart.
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Skill Drill

# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan", linewidth=2, label="Chicago")
# Create labels for the x and y axes.
ax.set_ylabel("Date")
ax.set_xlabel("Fare($)")
# Set the y limit between 0 and 45.

ax.set_xlim(0, 45)
# Create a title.
ax.set_title("PyBer Fare by Month")
ax.invert_yaxis()
# Add the legend.
ax.legend()

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
# Create MATLAB scatter plotting chart
plt.scatter(y_axis, x_axis, color='red', s=100, label='Chicago')
# Create a title
plt.title('PyBar Fare by Month')
# Label the axes
plt.xlabel('Fare($)')
plt.ylabel('Date')
# Add Legend
plt.legend()
# Invert the month label.
plt.gca().invert_yaxis()
# Show results
plt.show()

# %%
# Create MATLAB bubble scatter plotting chart
plt.scatter(x_axis, y_axis)

plt.scatter(x_axis, y_axis, s=y_axis)

# Create a title
plt.title('PyBar Fare by Month')
# Label the axes
plt.xlabel('Fare($)')
plt.ylabel('Date')
# Add Legend
plt.legend()

# Show results
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Create MATLAB bubble scatter plotting chart
plt.scatter(x_axis, y_axis)
plt.scatter(x_axis, y_axis, s=y_axis_larger)

y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)



# Show result
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-0ca8c1dda3b4> in <module>
#       1 # Create MATLAB bubble scatter plotting chart
#       2 plt.scatter(x_axis, y_axis)
# ----> 3 plt.scatter(x_axis, y_axis, s=y_axis_larger)
#       4
#       5 y_axis_larger = []
#
# NameError: name 'y_axis_larger' is not defined

# %%
# Create MATLAB bubble scatter plotting chart
plt.scatter(x_axis, y_axis)
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])



# Show result
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, color = 'blue', s = [i * 3 for i in y_axis])
# Create labels for the x and y axes.
ax.set_ylabel("Date")
ax.set_xlabel("Fare($)")
# Set the y limit between 0 and 45.
ax.set_xlim(0, 45)
# Create a title.
ax.set_title("PyBer Fare by Month")
ax.invert_yaxis()
# Add the legend.
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x221b6a6fd08>,
#   <matplotlib.patches.Wedge at 0x221b6a11608>,
#   <matplotlib.patches.Wedge at 0x221b6ac31c8>,
#   <matplotlib.patches.Wedge at 0x221b6a3f188>,
#   <matplotlib.patches.Wedge at 0x221b6a76308>,
#   <matplotlib.patches.Wedge at 0x221b6a7ca08>,
#   <matplotlib.patches.Wedge at 0x221b6a3ad48>,
#   <matplotlib.patches.Wedge at 0x221b6a2d848>,
#   <matplotlib.patches.Wedge at 0x221b6a76588>,
#   <matplotlib.patches.Wedge at 0x221b6a7cac8>,
#   <matplotlib.patches.Wedge at 0x221b6acaf88>,
#   <matplotlib.patches.Wedge at 0x221b6931988>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
# Detail oriented pie chart
fig, ax = plt.subplots()
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
#ax.subplots(figsize=(8, 8))
ax.pie(y_axis,labels=x_axis)
ax.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')
ax.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-011dc1932221> in <module>
#      10     labels=x_axis,
#      11     autopct='%.1f%%')
# ---> 12 ax.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'
